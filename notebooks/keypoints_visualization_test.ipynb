# %%
import json
import os
import cv2
import math

# %%
json_file_name = "../data/first_100samples/project-33-at-2022-05-03-11-23-ff2e8d68.json"

# %%
f = open (json_file_name, "r")
 
# Reading from file
data = json.loads(f.read())

# %% [markdown]
# ### understanding the structure of the json file

# %%
len(data)
# Out:
# 104

# %%
data[0].keys()
# Out:
# dict_keys(['id', 'annotations', 'file_upload', 'drafts', 'predictions', 'data', 'meta', 'created_at', 'updated_at', 'project'])

# %%
x= data[0]['data']
x
# Out:
# {'img': '/data/upload/33/6c0d4099-img_171461650020-010.jpg'}

# %%
x['img'].split("/")[-1].split("-", maxsplit=1)[-1]
# Out:
# 'img_171461650020-010.jpg'

# %%
data[7]['annotations'][0]
# Out:
# {'id': 146869,
#  'completed_by': 6,
#  'result': [{'id': 'UlG7GEdLFe',
#    'type': 'keypointlabels',
#    'value': {'x': 70.66666666666667,
#     'y': 27.710843373493976,
#     'width': 0.26666666666666666,
#     'keypointlabels': ['lower_right']},
#    'origin': 'manual',
#    'to_name': 'img-1',
#    'from_name': 'kp-1',
#    'image_rotation': 0,
#    'original_width': 1296,
#    'original_height': 861},
#   {'id': 'IZnyNhwK5u',
#    'type': 'keypointlabels',
#    'value': {'x': 73.6,
#     'y': 9.839357429718875,
#     'width': 0.26666666666666666,
#     'keypointlabels': ['top_right']},
#    'origin': 'manual',
#    'to_name': 'img-1',
#    'from_name': 'kp-1',
#    'image_rotation': 0,
#    'original_width': 1296,
#    'original_height': 861},
#   {'id': 'mlc61W3Zlf',
#    'type': 'keypointlabels',
#    'value': {'x': 37.06666666666667,
#     'y': 22.48995983935743,
#     'width': 0.26666666666666666,
#     'keypointlabels': ['lower_left']},
#    'origin': 'manual',
#    'to_name': 'img-1',
#    'from_name': 'kp-1',
#    'image_rotation': 0,
#    'original_width': 1296,
#    'original_height': 861},
#   {'id': 'Ylh_jIDKxE',
#    'type': 'keypointlabels',
#    'value': {'x': 47.333333333333336,
#     'y': 8.433734939759036,
#     'width': 0.26666666666666666,
#     'keypointlabels': ['top_left']},
#    'origin': 'manual',
#    'to_name': 'img-1',
#    'from_name': 'kp-1',
#    'image_rotation': 0,
#    'original_width': 1296,
#    'original_height': 861}],
#  'was_cancelled': False,
#  'ground_truth': False,
#  'created_at': '2022-05-03T10:43:48.358724Z',
#  'updated_at': '2022-05-03T10:43:48.358740Z',
#  'lead_time': 46.992,
#  'prediction': {},
#  'result_count': 0,
#  'task': 187254,
#  'parent_prediction': None,
#  'parent_annotation': None}

# %%
data[0]['annotations'][0].keys()
# Out:
# dict_keys(['id', 'completed_by', 'result', 'was_cancelled', 'ground_truth', 'created_at', 'updated_at', 'lead_time', 'prediction', 'result_count', 'task', 'parent_prediction', 'parent_annotation'])

# %%
len(data[3]['annotations'])
# Out:
# 1

# %%
data[1]['annotations'][0]['result']
# Out:
# [{'id': 'BPmXAWupIo',
#   'type': 'keypointlabels',
#   'value': {'x': 9.333333333333334,
#    'y': 14,
#    'width': 0.26666666666666666,
#    'keypointlabels': ['lower_right']},
#   'origin': 'manual',
#   'to_name': 'img-1',
#   'from_name': 'kp-1',
#   'image_rotation': 0,
#   'original_width': 967,
#   'original_height': 967}]

# %%
data[0]['annotations'][0]['result'][1]["original_width"]
# Out:
# 1200

# %%
points_dict
# Out:
# dict_keys([])

# %% [markdown]
# #### ploting results

# %%
image_keypoints= {}
image_dir = "C:/Users/AtenaFadaei/Documents/noimos/noimos_Working/Codes/windshield_frame_detector/data/first_100samples/100_Samples/"
image_save_dir = "C:/Users/AtenaFadaei/Documents/noimos/noimos_Working/Codes/windshield_frame_detector/data/first_100samples/results/"
for idx, image in enumerate(data):
    img_points ={}
    img_name = image["data"]['img'].split("/")[-1].split("-", maxsplit=1)[-1]
    image_path = os.path.join(image_dir, img_name)
    image_path = image_dir+ img_name
    image_save_path = os.path.join(image_save_dir, img_name)
    image_save_path = image_save_dir+ img_name
    img =cv2.imread(image_path)
    annotation = image ['annotations'][0]['result']
    points_dict = {}
    for cnt, point in enumerate(annotation):
        label = point['value']['keypointlabels'][0]
        x = point['value']['x']
        y = point['value']['y']
        original_width= point["original_width"]
        original_height= point["original_height"]
        points_dict[label]=(math.floor(x*original_width/100),math.floor((y)*original_height/100))
        #points_dict[label]=(math.floor(y*original_height/100),math.floor(x*original_width/100))
        print(points_dict[label])
        radius= 3
        if label == "lower_right":
            img = cv2.circle(img, (points_dict[label][0], points_dict[label][1]), radius, (255, 0, 0), -1)
        elif label == "lower_left":
            img = cv2.circle(img, (points_dict[label][0], points_dict[label][1]), radius, (0, 0, 255), -1)
        elif label == "top_right":
            img = cv2.circle(img, (points_dict[label][0], points_dict[label][1]), radius, (0, 255, 137), -1)
        elif label == "top_left":
            img = cv2.circle(img, (points_dict[label][0], points_dict[label][1]), radius, (188, 255, 0), -1)
            
    image_keypoints[img_name]=points_dict
        
    cv2.imwrite(image_save_path, img)
# Out:
# (254, 327)
# (670, 15)
# (9, 274)
# (315, 25)
# (90, 135)
# (240, 155)
# (828, 150)
# (622, 378)
# (820, 333)
# (457, 230)
# (641, 220)
# (675, 190)
# (768, 316)
# (309, 290)
# (356, 161)
# (282, 70)
# (686, 162)
# (394, 196)
# (710, 378)
# (1687, 375)
# (872, 107)
# (1532, 107)
# (915, 238)
# (953, 84)
# (480, 193)
# (613, 72)
# (232, 275)
# (1054, 273)
# (868, 330)
# (349, 331)
# (338, 185)
# (720, 196)
# (252, 219)
# (626, 253)
# (415, 96)
# (700, 96)
# (364, 212)
# (744, 195)
# (292, 55)
# (593, 73)
# (486, 213)
# (983, 247)
# (614, 60)
# (999, 58)
# (640, 225)
# (6, 322)
# (520, 116)
# (947, 119)
# (529, 214)
# (792, 195)
# (446, 94)
# (689, 84)
# (326, 193)
# (536, 211)
# (476, 64)
# (708, 60)
# (675, 193)
# (259, 124)
# (497, 115)
# (251, 49)
# (417, 47)
# (175, 126)
# (412, 146)
# (268, 60)
# (450, 54)
# (964, 146)
# (417, 135)
# (473, 336)
# (1004, 189)
# (349, 99)
# (749, 37)
# (428, 349)
# (896, 278)
# (605, 242)
# (823, 438)
# (364, 271)
# (767, 316)
# (593, 130)
# (901, 134)
# (429, 112)
# (449, 58)
# (333, 110)
# (813, 84)
# (132, 205)
# (539, 223)
# (279, 85)
# (581, 79)
# (212, 102)
# (437, 149)
# (289, 38)
# (471, 48)
# (231, 151)
# (436, 118)
# (363, 52)
# (196, 58)
# (335, 261)
# (661, 244)
# (535, 145)
# (298, 142)
# (319, 243)
# (694, 289)
# (739, 152)
# (460, 135)
# (472, 283)
# (918, 283)
# (878, 177)
# (564, 177)
# (616, 78)
# (447, 335)
# (570, 376)
# (574, 258)
# (714, 261)
# (494, 72)
# (213, 84)
# (260, 14)
# (456, 5)
# (205, 170)
# (406, 138)
# (315, 82)
# (155, 94)
# (220, 149)
# (421, 167)
# (299, 94)
# (451, 96)
# (393, 247)
# (219, 177)
# (215, 150)
# (421, 166)
# (299, 94)
# (448, 98)
# (397, 242)
# (217, 175)
# (411, 252)
# (823, 218)
# (414, 134)
# (715, 120)
# (385, 280)
# (321, 175)
# (865, 316)
# (870, 221)
# (118, 180)
# (679, 316)
# (850, 238)
# (527, 193)
# (354, 202)
# (741, 167)
# (328, 77)
# (630, 62)
# (201, 115)
# (429, 154)
# (488, 67)
# (304, 47)
# (233, 58)
# (625, 78)
# (290, 128)
# (215, 74)
# (423, 164)
# (229, 166)
# (451, 101)
# (303, 116)
# (235, 152)
# (407, 149)
# (199, 96)
# (328, 99)
# (200, 104)
# (418, 113)
# (234, 52)
# (385, 62)
# (191, 100)
# (405, 93)
# (197, 38)
# (351, 42)
# (252, 68)
# (451, 98)
# (314, 20)
# (463, 36)
# (130, 94)
# (503, 104)
# (458, 196)
# (199, 90)
# (469, 251)
# (889, 338)
# (983, 142)
# (650, 125)
# (474, 242)
# (949, 204)
# (387, 44)
# (734, 37)
# (741, 116)
# (782, 354)
# (713, 6)
# (553, 211)
# (459, 10)
# (1001, 134)
# (397, 299)
# (792, 268)
# (400, 189)
# (686, 171)
# (281, 140)
# (359, 22)
# (45, 95)
# (184, 8)
# (211, 124)
# (468, 128)
# (249, 54)
# (434, 58)
# (288, 328)
# (142, 498)
# (288, 331)
# (141, 498)
# (327, 213)
# (744, 185)
# (245, 25)
# (555, 32)
# (562, 333)
# (904, 363)
# (691, 230)
# (951, 246)
# (476, 307)
# (878, 270)
# (448, 180)
# (737, 168)
# (54, 317)
# (331, 379)
# (292, 170)
# (531, 180)
# (442, 263)
# (915, 247)
# (731, 116)
# (390, 106)
# (361, 287)
# (755, 314)
# (581, 161)
# (875, 149)
# (180, 128)
# (471, 125)
# (221, 48)
# (428, 45)
# (63, 106)
# (464, 98)
# (521, 88)
# (125, 94)
# (198, 94)
# (526, 117)
# (335, 164)
# (492, 141)
# (231, 58)
# (360, 56)
# (297, 96)
# (1004, 61)
# (331, 232)
# (811, 328)
# (890, 201)
# (443, 319)
# (583, 249)
# (442, 128)
# (853, 240)
# (552, 240)
# (997, 263)
# (693, 137)
# (1026, 132)
# (283, 151)
# (825, 137)
# (386, 184)
# (685, 126)
# (326, 62)
# (554, 30)
# (371, 186)
# (652, 223)
# (693, 106)
# (480, 94)
# (273, 105)
# (779, 102)
# (278, 103)
# (779, 100)
# (221, 134)
# (401, 136)
# (291, 77)
# (424, 68)
# (251, 100)
# (521, 106)
# (316, 38)
# (511, 32)
# (624, 656)
# (1490, 692)
# (767, 352)
# (1508, 361)
# (1146, 668)
# (1323, 373)
# (508, 28)
# (129, 32)
# (211, 131)
# (490, 78)
# (313, 57)
# (431, 183)
# (145, 213)
# (388, 23)
# (353, 136)
# (631, 165)
# (473, 53)
# (688, 59)
# (677, 21)
# (451, 39)
# (814, 110)
# (525, 156)
# (324, 112)
# (708, 88)
# (751, 116)
# (918, 214)
# (105, 79)
# (481, 238)
# (697, 249)
# (555, 145)
# (312, 151)
# (397, 270)

# %%
image_keypoints
# Out:
# {'img_171461650020-010.jpg': {'lower_right': (254, 327),
#   'top_right': (670, 15),
#   'lower_left': (9, 274),
#   'top_left': (315, 25)},
#  'img_169768040023-001.png': {'lower_right': (90, 135)},
#  'img_221995250001-001.jpg': {'top_left': (240, 155), 'top_right': (828, 150)},
#  'img_201249030047-003.png': {'lower_left': (622, 378),
#   'lower_right': (820, 333),
#   'top_left': (457, 230),
#   'top_right': (641, 220)},
#  'img_201249030047-001.png': {'top_right': (675, 190),
#   'lower_right': (768, 316),
#   'lower_left': (309, 290),
#   'top_left': (356, 161)},
#  'img_201228310120-002.jpg': {'top_left': (282, 70),
#   'lower_right': (686, 162),
#   'lower_left': (394, 196)},
#  'img_201222230058-000.jpg': {'lower_left': (710, 378),
#   'lower_right': (1687, 375),
#   'top_left': (872, 107),
#   'top_right': (1532, 107)},
#  'img_201206580298-000.jpg': {'lower_right': (915, 238),
#   'top_right': (953, 84),
#   'lower_left': (480, 193),
#   'top_left': (613, 72)},
#  'img_201191510068-001.jpg': {'top_left': (232, 275),
#   'top_right': (1054, 273)},
#  'img_201191510068-000.jpg': {'lower_right': (868, 330),
#   'lower_left': (349, 331),
#   'top_left': (338, 185),
#   'top_right': (720, 196)},
#  'img_201166291667-012.jpg': {'lower_left': (252, 219),
#   'lower_right': (626, 253),
#   'top_left': (415, 96),
#   'top_right': (700, 96)},
#  'img_201166291667-011.jpg': {'lower_left': (364, 212),
#   'lower_right': (744, 195),
#   'top_left': (292, 55),
#   'top_right': (593, 73)},
#  'img_171478440012-000.jpg': {'lower_left': (486, 213),
#   'lower_right': (983, 247),
#   'top_left': (614, 60),
#   'top_right': (999, 58)},
#  'img_171461650020-014.jpg': {'lower_right': (640, 225),
#   'lower_left': (6, 322)},
#  'img_171461650020-007.jpg': {'lower_left': (520, 116),
#   'lower_right': (947, 119)},
#  'img_171461650020-001.jpg': {'lower_left': (529, 214),
#   'lower_right': (792, 195),
#   'top_left': (446, 94),
#   'top_right': (689, 84)},
#  'img_171461650020-000.jpg': {'lower_left': (326, 193),
#   'lower_right': (536, 211),
#   'top_left': (476, 64),
#   'top_right': (708, 60)},
#  'img_171461650019-000.jpg': {'lower_left': (675, 193)},
#  'img_171396800004-009.jpg': {'lower_left': (259, 124),
#   'lower_right': (497, 115),
#   'top_left': (251, 49),
#   'top_right': (417, 47)},
#  'img_171396800004-008.png': {'lower_left': (175, 126),
#   'lower_right': (412, 146),
#   'top_left': (268, 60),
#   'top_right': (450, 54)},
#  'img_171300070003-007.jpg': {'lower_right': (964, 146),
#   'lower_left': (417, 135)},
#  'img_171300070003-001.jpg': {'lower_left': (473, 336),
#   'lower_right': (1004, 189),
#   'top_left': (349, 99),
#   'top_right': (749, 37)},
#  'img_171300070003-000.jpg': {'lower_left': (428, 349),
#   'top_right': (896, 278),
#   'top_left': (605, 242),
#   'lower_right': (823, 438)},
#   'top_left': (231, 58),
#   'top_right': (360, 56)},
#  'img_163510930015-006.jpg': {'lower_left': (297, 96),
#   'lower_right': (1004, 61)},
#  'img_163510930015-004.jpg': {'lower_left': (331, 232)},
#  'img_163510930015-001.jpg': {'lower_right': (811, 328),
#   'top_right': (890, 201),
#   'lower_left': (443, 319)},
#  'img_163510930015-000.jpg': {'lower_left': (583, 249),
#   'top_left': (442, 128),
#   'lower_right': (853, 240)},
#  'img_163370670009-008.jpg': {},
#  'img_163370670009-003.jpg': {'lower_left': (552, 240),
#   'lower_right': (997, 263),
#   'top_left': (693, 137),
#   'top_right': (1026, 132)},
#  'img_163370670009-000.jpg': {'lower_left': (283, 151),
#   'lower_right': (825, 137)},
#  'img_163155710004-004.jpg': {'lower_left': (386, 184),
#   'lower_right': (685, 126),
#   'top_left': (326, 62),
#   'top_right': (554, 30)},
#  'img_163155710004-003.jpg': {'lower_left': (371, 186),
#   'lower_right': (652, 223),
#   'top_right': (693, 106),
#   'top_left': (480, 94)},
#  'img_162977270007-007.png': {'lower_left': (273, 105),
#   'lower_right': (779, 102)},
#  'img_162977270007-003.jpg': {'lower_left': (278, 103),
#   'lower_right': (779, 100)},
#  'img_162916290014-002.jpg': {'lower_left': (221, 134),
#   'lower_right': (401, 136),
#   'top_left': (291, 77),
#   'top_right': (424, 68)},
#  'img_162916290014-001.jpg': {'lower_left': (251, 100),
#   'lower_right': (521, 106),
#   'top_left': (316, 38),
#   'top_right': (511, 32)},
#  'img_162375860013-004.jpg': {'lower_left': (624, 656),
#   'lower_right': (1490, 692),
#   'top_left': (767, 352),
#   'top_right': (1508, 361)},
#  'img_162375860013-000.jpg': {'lower_right': (1146, 668),
#   'top_right': (1323, 373)},
#  'img_161366540015-003.jpg': {'lower_right': (508, 28),
#   'lower_left': (129, 32)},
#  'img_161366540015-002.jpg': {'lower_left': (211, 131),
#   'top_right': (490, 78),
#   'top_left': (313, 57),
#   'lower_right': (431, 183)},
#  'img_161216030011-020.png': {'lower_right': (145, 213),
#   'top_right': (388, 23)},
#  'img_161216030011-019.jpg': {'lower_left': (353, 136),
#   'lower_right': (631, 165),
#   'top_left': (473, 53),
#   'top_right': (688, 59)},
#  'img_161216030011-017.jpg': {'top_right': (677, 21),
#   'top_left': (451, 39),
#   'lower_right': (814, 110),
#   'lower_left': (525, 156)},
#  'img_161216030011-014.jpg': {'lower_left': (324, 112),
#   'lower_right': (708, 88)},
#  'img_161216030011-004.jpg': {'top_left': (751, 116),
#   'lower_left': (918, 214)},
#  'img_161170790019-001.jpg': {'top_left': (105, 79), 'lower_left': (481, 238)},
#  'img_161170790019-000.jpg': {'lower_right': (697, 249),
#   'top_right': (555, 145),
#   'top_left': (312, 151),
#   'lower_left': (397, 270)},
#  'img_160748940021-000.jpg': {}}

# %%
def plot_labelstudio_keypoints(json_file_path, read_img_dir, write_img_dir):
    """ a function to read keypoints lables in Label studio jso format and visualized them on the images
    Args:
        json_file_path: path to the json file
        read_img_dir: the directory where all images are there
        write_img_dir: the directory where results will be saved
        
    Returns:
        image_keypoints_dict: a dictionary like {img_name: {'keypointlabel1': (x1,y1), 'keypointlabel2': (x2,y2), ...}}
    """
    f = open (json_file_path, "r")
    data = json.loads(f.read())
    image_keypoints_dict= {}
    for idx, image in enumerate(data):
        img_points ={}
        img_name = image["data"]['img'].split("/")[-1].split("-", maxsplit=1)[-1]
        image_path = os.path.join(image_dir, img_name)
        image_path = image_dir+ img_name
        image_save_path = os.path.join(image_save_dir, img_name)
        image_save_path = image_save_dir+ img_name
        img =cv2.imread(image_path)
        annotation = image ['annotations'][0]['result']
        points_dict = {}
        for cnt, point in enumerate(annotation):
            label = point['value']['keypointlabels'][0]
            x = point['value']['x']
            y = point['value']['y']
            original_width= point["original_width"]
            original_height= point["original_height"]
            points_dict[label]=(math.floor(x*original_width/100),math.floor((y)*original_height/100))
            radius= 3
            if label == "lower_right":
                img = cv2.circle(img, (points_dict[label][0], points_dict[label][1]), radius, (255, 0, 0), -1)
            elif label == "lower_left":
                img = cv2.circle(img, (points_dict[label][0], points_dict[label][1]), radius, (0, 0, 255), -1)
            elif label == "top_right":
                img = cv2.circle(img, (points_dict[label][0], points_dict[label][1]), radius, (0, 255, 137), -1)
            elif label == "top_left":
                img = cv2.circle(img, (points_dict[label][0], points_dict[label][1]), radius, (188, 255, 0), -1)
            
        image_keypoints[img_name]=points_dict
        
        cv2.imwrite(image_save_path, img)
    return image_keypoints_dict

# %%
x = plot_labelstudio_keypoints(json_file_name,image_dir, image_save_dir )
# Out:
# (254, 327)
# (670, 15)
# (9, 274)
# (315, 25)
# (90, 135)
# (240, 155)
# (828, 150)
# (622, 378)
# (820, 333)
# (457, 230)
# (641, 220)
# (675, 190)
# (768, 316)
# (309, 290)
# (356, 161)
# (282, 70)
# (686, 162)
# (394, 196)
# (710, 378)
# (1687, 375)
# (872, 107)
# (1532, 107)
# (915, 238)
# (953, 84)
# (480, 193)
# (613, 72)
# (232, 275)
# (1054, 273)
# (868, 330)
# (349, 331)
# (338, 185)
# (720, 196)
# (252, 219)
# (626, 253)
# (415, 96)
# (700, 96)
# (364, 212)
# (744, 195)
# (292, 55)
# (593, 73)
# (486, 213)
# (983, 247)
# (614, 60)
# (999, 58)
# (640, 225)
# (6, 322)
# (520, 116)
# (947, 119)
# (529, 214)
# (792, 195)
# (446, 94)
# (689, 84)
# (326, 193)
# (536, 211)
# (476, 64)
# (708, 60)
# (675, 193)
# (259, 124)
# (497, 115)
# (251, 49)
# (417, 47)
# (175, 126)
# (412, 146)
# (268, 60)
# (450, 54)
# (964, 146)
# (417, 135)
# (473, 336)
# (1004, 189)
# (349, 99)
# (749, 37)
# (428, 349)
# (896, 278)
# (605, 242)
# (823, 438)
# (364, 271)
# (767, 316)
# (593, 130)
# (901, 134)
# (429, 112)
# (449, 58)
# (333, 110)
# (813, 84)
# (132, 205)
# (539, 223)
# (279, 85)
# (581, 79)
# (212, 102)
# (437, 149)
# (289, 38)
# (471, 48)
# (231, 151)
# (436, 118)
# (363, 52)
# (196, 58)
# (335, 261)
# (661, 244)
# (535, 145)
# (298, 142)
# (319, 243)
# (694, 289)
# (739, 152)
# (460, 135)
# (472, 283)
# (918, 283)
# (878, 177)
# (564, 177)
# (616, 78)
# (447, 335)
# (570, 376)
# (574, 258)
# (714, 261)
# (494, 72)
# (213, 84)
# (260, 14)
# (456, 5)
# (205, 170)
# (406, 138)
# (315, 82)
# (155, 94)
# (220, 149)
# (421, 167)
# (299, 94)
# (451, 96)
# (393, 247)
# (219, 177)
# (215, 150)
# (421, 166)
# (299, 94)
# (448, 98)
# (397, 242)
# (217, 175)
# (411, 252)
# (823, 218)
# (414, 134)
# (715, 120)
# (385, 280)
# (321, 175)
# (865, 316)
# (870, 221)
# (118, 180)
# (679, 316)
# (850, 238)
# (527, 193)
# (354, 202)
# (741, 167)
# (328, 77)
# (630, 62)
# (201, 115)
# (429, 154)
# (488, 67)
# (304, 47)
# (233, 58)
# (625, 78)
# (290, 128)
# (215, 74)
# (423, 164)
# (229, 166)
# (451, 101)
# (303, 116)
# (235, 152)
# (407, 149)
# (199, 96)
# (328, 99)
# (200, 104)
# (418, 113)
# (234, 52)
# (385, 62)
# (191, 100)
# (405, 93)
# (197, 38)
# (351, 42)
# (252, 68)
# (451, 98)
# (314, 20)
# (463, 36)
# (130, 94)
# (503, 104)
# (458, 196)
# (199, 90)
# (469, 251)
# (889, 338)
# (983, 142)
# (650, 125)
# (474, 242)
# (949, 204)
# (387, 44)
# (734, 37)
# (741, 116)
# (782, 354)
# (713, 6)
# (553, 211)
# (459, 10)
# (1001, 134)
# (397, 299)
# (792, 268)
# (400, 189)
# (686, 171)
# (281, 140)
# (359, 22)
# (45, 95)
# (184, 8)
# (211, 124)
# (468, 128)
# (249, 54)
# (434, 58)
# (288, 328)
# (142, 498)
# (288, 331)
# (141, 498)
# (327, 213)
# (744, 185)
# (245, 25)
# (555, 32)
# (562, 333)
# (904, 363)
# (691, 230)
# (951, 246)
# (476, 307)
# (878, 270)
# (448, 180)
# (737, 168)
# (54, 317)
# (331, 379)
# (292, 170)
# (531, 180)
# (442, 263)
# (915, 247)
# (731, 116)
# (390, 106)
# (361, 287)
# (755, 314)
# (581, 161)
# (875, 149)
# (180, 128)
# (471, 125)
# (221, 48)
# (428, 45)
# (63, 106)
# (464, 98)
# (521, 88)
# (125, 94)
# (198, 94)
# (526, 117)
# (335, 164)
# (492, 141)
# (231, 58)
# (360, 56)
# (297, 96)
# (1004, 61)
# (331, 232)
# (811, 328)
# (890, 201)
# (443, 319)
# (583, 249)
# (442, 128)
# (853, 240)
# (552, 240)
# (997, 263)
# (693, 137)
# (1026, 132)
# (283, 151)
# (825, 137)
# (386, 184)
# (685, 126)
# (326, 62)
# (554, 30)
# (371, 186)
# (652, 223)
# (693, 106)
# (480, 94)
# (273, 105)
# (779, 102)
# (278, 103)
# (779, 100)
# (221, 134)
# (401, 136)
# (291, 77)
# (424, 68)
# (251, 100)
# (521, 106)
# (316, 38)
# (511, 32)
# (624, 656)
# (1490, 692)
# (767, 352)
# (1508, 361)
# (1146, 668)
# (1323, 373)
# (508, 28)
# (129, 32)
# (211, 131)
# (490, 78)
# (313, 57)
# (431, 183)
# (145, 213)
# (388, 23)
# (353, 136)
# (631, 165)
# (473, 53)
# (688, 59)
# (677, 21)
# (451, 39)
# (814, 110)
# (525, 156)
# (324, 112)
# (708, 88)
# (751, 116)
# (918, 214)
# (105, 79)
# (481, 238)
# (697, 249)
# (555, 145)
# (312, 151)
# (397, 270)
